# %% [markdown]
# # Trying to make things work

# %%
import pandas as pd
import requests

# %%
dlurl = "https://www.redfin.com/stingray/api/gis-csv?al=1&market=twincities&min_stories=1&num_homes=350&ord=days-on-redfin-asc&page_number=1&region_id=10943&region_type=6&sf=1,2,5,6,7&status=9&uipt=1,4&v=8"

session = requests.Session()
session.headers.update({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.35'})

# %%
r = session.get(dlurl)
r.status_code
# Out:
# 200

# %%
resptext = r.content

# %%
r.textheaders['content-type']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-a3f3ecbf74ff> in <module>()
# ----> 1 r.textheaders['content-type']
#
# AttributeError: 'Response' object has no attribute 'textheaders'

# %% [raw]
# r.type

# %%
rawData = pd.read_csv(io.StringIO(resptext.decode('utf-8')))

# %%
rawData
# Out:
#        SALE TYPE  SOLD DATE              PROPERTY TYPE                ADDRESS  \
# 0    MLS Listing        NaN  Single Family Residential        3437 Zane Ave N
# 1    MLS Listing        NaN  Single Family Residential          5253 N 6th St
# 2    MLS Listing        NaN  Single Family Residential    5025 Sheridan Ave S
# 3    MLS Listing        NaN  Single Family Residential     5601 Emerson Ave S
# 4    MLS Listing        NaN  Single Family Residential         4809 3rd Ave S
# 5    MLS Listing        NaN  Single Family Residential       5936 Upton Ave S
# 6    MLS Listing        NaN  Single Family Residential     4249 Edinbrook Ter
# 7    MLS Listing        NaN  Single Family Residential        5229 39th Ave S
# 8    MLS Listing        NaN    Multi-Family (2-4 Unit)         4505 2nd Ave S
# 9    MLS Listing        NaN    Multi-Family (2-4 Unit)      2410 Colfax Ave S
# 10   MLS Listing        NaN  Single Family Residential      7136 Newton Ave N
# ...

# %%
rawData.to_csv('./output/test.csv')
